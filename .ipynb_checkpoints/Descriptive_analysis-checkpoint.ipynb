# %%
import pandas as pd

df = pd.read_csv('Data(in).csv')
df
# Out:
#    Country   Age   Salary Purchased
# 0      UAE  44.0  72000.0        No
# 1  Bahrain  27.0  48000.0       Yes
# 2      KSA  30.0  54000.0        No
# 3  Bahrain  38.0  61000.0        No
# 4      KSA  40.0      NaN       Yes
# 5      UAE  35.0  58000.0       Yes
# 6  Bahrain   NaN  52000.0        No
# 7      UAE  48.0  79000.0       Yes
# 8      KSA  50.0  83000.0        No
# 9      UAE  37.0  67000.0       Yes
